# %%
# !pip install pybboxes albumentations==1.3.0 --upgrade typing-extensions torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: pybboxes in /home/work/.local/lib/python3.8/site-packages (0.1.6)
# Requirement already satisfied: albumentations==1.3.0 in /home/work/.local/lib/python3.8/site-packages (1.3.0)
# Requirement already satisfied: typing-extensions in /home/work/.local/lib/python3.8/site-packages (4.8.0)
# Requirement already satisfied: torch in /home/work/.local/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: qudida>=0.0.4 in /home/work/.local/lib/python3.8/site-packages (from albumentations==1.3.0) (0.0.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from albumentations==1.3.0) (1.7.2)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.8/dist-packages (from albumentations==1.3.0) (4.5.4.58)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from albumentations==1.3.0) (5.3.1)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.8/dist-packages (from albumentations==1.3.0) (0.16.2)
# Requirement already satisfied: numpy>=1.11.1 in /home/work/.local/lib/python3.8/site-packages (from albumentations==1.3.0) (1.22.4)
# Requirement already satisfied: sympy in /home/work/.local/lib/python3.8/site-packages (from torch) (1.12)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.8/dist-packages (from torch) (2021.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/work/.local/lib/python3.8/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/work/.local/lib/python3.8/site-packages (from torch) (12.1.105)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from torch) (3.0.12)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/work/.local/lib/python3.8/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/work/.local/lib/python3.8/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/work/.local/lib/python3.8/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/work/.local/lib/python3.8/site-packages (from torch) (2.18.1)
# Requirement already satisfied: triton==2.1.0 in /home/work/.local/lib/python3.8/site-packages (from torch) (2.1.0)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/work/.local/lib/python3.8/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/work/.local/lib/python3.8/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/work/.local/lib/python3.8/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (from torch) (2.5.1)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/work/.local/lib/python3.8/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from torch) (2.11.3)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/work/.local/lib/python3.8/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/work/.local/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.2.140)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.8/dist-packages (from qudida>=0.0.4->albumentations==1.3.0) (0.24.2)
# Requirement already satisfied: PyWavelets>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (1.1.1)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (2.9.0)
# Requirement already satisfied: pillow>=4.3.0 in /home/work/.local/lib/python3.8/site-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (10.0.1)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (3.4.2)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.8/dist-packages (from networkx->torch) (4.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->torch) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /home/work/.local/lib/python3.8/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==1.3.0) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.7 in /home/work/.local/lib/python3.8/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==1.3.0) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==1.3.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==1.3.0) (0.10.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations==1.3.0) (0.14.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations==1.3.0) (2.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from cycler>=0.10->matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==1.3.0) (1.15.0)
# WARNING: You are using pip version 21.3.1; however, version 23.2.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import os
from sklearn.model_selection import train_test_split
import shutil
from shutil import copyfile
import numpy as np
from collections import defaultdict
import glob
import random
import cv2
import albumentations as A

# %%
def seed_everything(seed=42):
    random.seed(seed) # random
    np.random.seed(seed) # np
    
seed_everything()

# %%
DATA_PATH = os.getcwd()
DATA_PATH
# Out:
# '/home/work/KISTI_PCB2'

# %%
# ipynb.checkpoint 삭제하는 코드
# rm -rf `find -type d -name .ipynb_checkpoints`

# %%
BOXING_TXT = 'BOXING_TXT_1013'
Client_PCB = ['C1_PCB', 'C2_PCB']
zip_list = ['POP_CORN_TXT', 'DELAMINATION_TXT', 'SCRATCH_TXT']

all_files = []

for folder_name in zip_list:
    path_an = f"./{BOXING_TXT}/{folder_name}"
    for path, subdirs, files in os.walk(path_an):
#         print([path, subdirs, files])
        for name in files:
            all_files.append(os.path.join(folder_name, name))

new_files = []
all_labels = []
for file_name in all_files:
    new_name = file_name.replace("SCRATCH_TXT", "BASIC_MATERIAL_SCRATCH_TXT")
    new_files.append(new_name)
    
    if 'SCRATCH' in new_name:
        all_labels.append(0)
    elif 'DELAMINATION' in new_name:
        all_labels.append(1)
    elif 'POP_CORN' in new_name:
        all_labels.append(2)
    else:
        print('no named file')
        break

all_files = new_files
print(len(all_files), len(all_labels))
# Out:
# 485 485

# %% [markdown]
# # Object Detection에 사용될 데이터셋 생성
# - *BADPCB만 사용*
# - PCB (중앙집중형 Object Detection에 사용)
# - C1_PCB (Client 1 Object Detection에 사용) - 중앙집중형 및 연합학습에 사용
# - C2_PCB (Client 2 Object Detection에 사용) - 중앙집중형 및 연합학습에 사용

# %%
X_train, X_test, y_train, y_test = train_test_split(all_files, all_labels, test_size = 0.1, stratify=all_labels, random_state=2023)

# %%
print('전체 데이터 이미지 수:' , end = ' ')
print(all_labels.count(0), all_labels.count(1), all_labels.count(2))
print('X_train 이미지 수:' , end = ' ')
print(sum(1 for item in X_train if "SCRATCH" in item), sum(1 for item in X_train if "DELAMINATION" in item), sum(1 for item in X_train if "POP_CORN" in item))
print('X_test 이미지 수:' , end = ' ')
print(sum(1 for item in X_test if "SCRATCH" in item), sum(1 for item in X_test if "DELAMINATION" in item), sum(1 for item in X_test if "POP_CORN" in item))
# Out:
# 전체 데이터 이미지 수: 79 53 353
# X_train 이미지 수: 71 48 317
# X_test 이미지 수: 8 5 36

# %%
# directory 삭제 함수
def remove_directory(directory_path):
    if os.path.exists(directory_path):
        shutil.rmtree(directory_path)
        print(f"Removed directory: {directory_path}")
    else:
        print(f"Directory does not exist: {directory_path}")

# directory 생성 함수
def create_directory(directory_path):
    os.makedirs(directory_path, exist_ok=True)
    print(f"Created directory: {directory_path}")
    
# 파일 복사 및 이름 변경 함수
def copy_and_rename_files(source_path, destination_path, subdirectory_name):
    for root, _, files in os.walk(source_path):
        for file_name in files:
            source_file_path = os.path.join(root, file_name)
            if os.path.exists(source_file_path):
                new_file_name = file_name.replace("/", "_")  # Replace '/' with '_'
                new_subdirectory_name = subdirectory_name
                if "SCRATCH" in subdirectory_name:
                    new_subdirectory_name = subdirectory_name.replace("SCRATCH", "BASIC_MATERIAL_SCRATCH")
                new_file_name = f"{new_subdirectory_name}_{new_file_name}"  # Add subdirectory name
                destination_file_path = os.path.join(destination_path, new_file_name)
                shutil.copy2(source_file_path, destination_file_path)
                # print(f"Copied {file_name} to {destination_path}{new_file_name}")
            else:
                print(f"{file_name} not found in {source_path}")

# label 복사 함수                
def shutil_labels(index_labels, source_directory, dest_directory):
    for filename in index_labels:
        source_path = os.path.join(source_directory, filename)
        dest_path = os.path.join(dest_directory, filename)

        # 원본 디렉토리에 해당 파일이 있는지 확인 후 복사
        if os.path.exists(source_path):
            shutil.copy(source_path, dest_path)
#             print(f"{source_directory + filename} 복사 완료")
        else:
            print(f"{source_directory + filename} 찾을 수 없음")

# image 복사 함수
def shutil_images(index_images, source_directory, dest_directory):
    for filename in index_images:
        source_path = os.path.join(source_directory, filename)
        dest_path = os.path.join(dest_directory, filename.replace('/', '_'))

        # 원본 디렉토리에 해당 파일이 있는지 확인 후 복사
        if os.path.exists(source_path):
            shutil.copy(source_path, dest_path)
#             print(f"{source_path} 복사 완료")
        else:
            print(f"{source_path} 찾을 수 없음")
            
# 파일 개수 확인
def get_files_count(folder_path):
    dirListing = os.listdir(folder_path)
    return len(dirListing)

# %% [markdown]
# ## PCB생성

# %%
# 디렉토리 삭제 및 생성
remove_directory('./PCB/dataset/images')
remove_directory('./PCB/dataset/labels')
remove_directory('./PCB/train/images')
remove_directory('./PCB/train/labels')
remove_directory('./PCB/valid/images')
remove_directory('./PCB/valid/labels')
remove_directory('./PCB/test/images')
remove_directory('./PCB/test/labels')

create_directory('./PCB/dataset/images')
create_directory('./PCB/dataset/labels')
create_directory('./PCB/train/images')
create_directory('./PCB/train/labels')
create_directory('./PCB/valid/images')
create_directory('./PCB/valid/labels')
create_directory('./PCB/test/images')
create_directory('./PCB/test/labels')
# Out:
# Removed directory: ./PCB/dataset/images
# Removed directory: ./PCB/dataset/labels
# Removed directory: ./PCB/train/images
# Removed directory: ./PCB/train/labels
# Removed directory: ./PCB/valid/images
# Removed directory: ./PCB/valid/labels
# Removed directory: ./PCB/test/images
# Removed directory: ./PCB/test/labels
# Created directory: ./PCB/dataset/images
# Created directory: ./PCB/dataset/labels
# Created directory: ./PCB/train/images
# Created directory: ./PCB/train/labels
# Created directory: ./PCB/valid/images
# Created directory: ./PCB/valid/labels
# Created directory: ./PCB/test/images
# Created directory: ./PCB/test/labels

# %%
# dataset/labels에 txt파일 복사
file_paths = [
    f"./{BOXING_TXT}/POP_CORN_TXT/",
    f"./{BOXING_TXT}/DELAMINATION_TXT/",
    f"./{BOXING_TXT}/SCRATCH_TXT/"
]

# %%
destination_directory = "./PCB/dataset/labels/"

# 주어진 파일 경로들에 대해 파일 복사 및 이름 변경 수행
for source_path in file_paths:
    subdirectory_name = source_path.split("/")[-2]  # Get the second-to-last part of the path
    copy_and_rename_files(source_path, destination_directory, subdirectory_name[:-4])

# %%
train_index, valid_index = train_test_split(X_train, test_size = 0.2, stratify=y_train, random_state=1234)
test_index = X_test

# %%
train_index_labels = np.array([filename.replace("_TXT", "").replace('/', '_') for filename in train_index])
valid_index_labels = np.array([filename.replace("_TXT", "").replace('/', '_') for filename in valid_index])
test_index_labels = np.array([filename.replace("_TXT", "").replace('/', '_') for filename in test_index])
train_index_images = np.array([filename.replace('_TXT', '').replace('.txt', '.png') for filename in train_index])
valid_index_images = np.array([filename.replace('_TXT', '').replace('.txt', '.png') for filename in valid_index])
test_index_images = np.array([filename.replace('_TXT', '').replace('.txt', '.png') for filename in test_index])

# %%
source_labels_directory = './PCB/dataset/labels/'
train_labels_directory = './PCB/train/labels/'
valid_labels_directory = './PCB/valid/labels/'
test_labels_directory = './PCB/test/labels/'
source_images_directory = './DATA/PCB_DEFECTS_230728/'
train_images_directory = './PCB/train/images/'
valid_images_directory = './PCB/valid/images/'
test_images_directory = './PCB/test/images/'

# %%
shutil_labels(train_index_labels, source_labels_directory, train_labels_directory)
shutil_labels(valid_index_labels, source_labels_directory, valid_labels_directory)
shutil_labels(test_index_labels, source_labels_directory, test_labels_directory)
shutil_images(train_index_images, source_images_directory, train_images_directory)
shutil_images(valid_index_images, source_images_directory, valid_images_directory)
shutil_images(test_index_images, source_images_directory, test_images_directory)

# %%
if __name__ == "__main__":
    print(get_files_count("./PCB/train/images/"), get_files_count("./PCB/train/labels/"), end = ' ')
    print(get_files_count("./PCB/valid/images/"), get_files_count("./PCB/valid/labels/"), end = ' ')
    print(get_files_count("./PCB/test/images/"), get_files_count("./PCB/test/labels/"))
# Out:
# 348 348 88 88 49 49

# %% [markdown]
# ## C1_PCB, C2_PCB 생성

# %%
# test set이 주어진다면 
# C1_files, C2_files, C1_labels, C2_labels = train_test_split(all_files, all_labels, test_size = 0.5, stratify=all_labels, random_state=1234)
C1_files, C2_files, C1_labels, C2_labels = train_test_split(X_train, y_train, test_size = 0.5, stratify=y_train, random_state=1234)

# %%
for client in ['C1_PCB', 'C2_PCB']:
    # 디렉토리 삭제 및 생성
    remove_directory(f'./{client}/dataset/images')
    remove_directory(f'./{client}/dataset/labels')
    remove_directory(f'./{client}/train/images')
    remove_directory(f'./{client}/train/labels')
    remove_directory(f'./{client}/valid/images')
    remove_directory(f'./{client}/valid/labels')
    remove_directory(f'./{client}/test/images')
    remove_directory(f'./{client}/test/labels')
    create_directory(f'./{client}/dataset/images')
    create_directory(f'./{client}/dataset/labels')
    create_directory(f'./{client}/train/images')
    create_directory(f'./{client}/train/labels')
    create_directory(f'./{client}/valid/images')
    create_directory(f'./{client}/valid/labels')
    create_directory(f'./{client}/test/images')
    create_directory(f'./{client}/test/labels')
    
    # dataset/labels에 txt파일 복사
    destination_directory = f"./{client}/dataset/labels/"

    # 주어진 파일 경로들에 대해 파일 복사 및 이름 변경 수행
    for source_path in file_paths:
        subdirectory_name = source_path.split("/")[-2]  # Get the second-to-last part of the path
        copy_and_rename_files(source_path, destination_directory, subdirectory_name[:-4])
# Out:
# Removed directory: ./C1_PCB/dataset/images
# Removed directory: ./C1_PCB/dataset/labels
# Removed directory: ./C1_PCB/train/images
# Removed directory: ./C1_PCB/train/labels
# Removed directory: ./C1_PCB/valid/images
# Removed directory: ./C1_PCB/valid/labels
# Removed directory: ./C1_PCB/test/images
# Removed directory: ./C1_PCB/test/labels
# Created directory: ./C1_PCB/dataset/images
# Created directory: ./C1_PCB/dataset/labels
# Created directory: ./C1_PCB/train/images
# Created directory: ./C1_PCB/train/labels
# Created directory: ./C1_PCB/valid/images
# Created directory: ./C1_PCB/valid/labels
# Created directory: ./C1_PCB/test/images
# Created directory: ./C1_PCB/test/labels
# Removed directory: ./C2_PCB/dataset/images
# Removed directory: ./C2_PCB/dataset/labels
# Removed directory: ./C2_PCB/train/images
# Removed directory: ./C2_PCB/train/labels
# Removed directory: ./C2_PCB/valid/images
# Removed directory: ./C2_PCB/valid/labels
# Removed directory: ./C2_PCB/test/images
# Removed directory: ./C2_PCB/test/labels
# Created directory: ./C2_PCB/dataset/images
# Created directory: ./C2_PCB/dataset/labels
# Created directory: ./C2_PCB/train/images
# Created directory: ./C2_PCB/train/labels
# Created directory: ./C2_PCB/valid/images
# Created directory: ./C2_PCB/valid/labels
# Created directory: ./C2_PCB/test/images
# Created directory: ./C2_PCB/test/labels

# %%
for idx, (files, labels) in enumerate([(C1_files, C1_labels), (C2_files, C2_labels)]):

    train_index, valid_index = train_test_split(files, test_size = 0.2, stratify=labels, random_state=1234)
    test_index = X_test
#     print(len(train_index), len(valid_index), len(test_index))

    train_index_labels = np.array([filename.replace("_TXT", "").replace('/', '_') for filename in train_index])
    valid_index_labels = np.array([filename.replace("_TXT", "").replace('/', '_') for filename in valid_index])
    test_index_labels = np.array([filename.replace("_TXT", "").replace('/', '_') for filename in test_index])
    train_index_images = np.array([filename.replace('_TXT', '').replace('.txt', '.png') for filename in train_index])
    valid_index_images = np.array([filename.replace('_TXT', '').replace('.txt', '.png') for filename in valid_index])
    test_index_images = np.array([filename.replace('_TXT', '').replace('.txt', '.png') for filename in test_index])
    
    # label C1_PCB과 C2_PCB에 분할
    if idx == 0:
        source_labels_directory = './C1_PCB/dataset/labels/'
        train_labels_directory = './C1_PCB/train/labels/'
        valid_labels_directory = './C1_PCB/valid/labels/'
        test_labels_directory = './C1_PCB/test/labels/'
        source_images_directory = './DATA/PCB_DEFECTS_230728/'
        train_images_directory = './C1_PCB/train/images/'
        valid_images_directory = './C1_PCB/valid/images/'
        test_images_directory = './C1_PCB/test/images/'

    else:
        source_labels_directory = './C2_PCB/dataset/labels/'
        train_labels_directory = './C2_PCB/train/labels/'
        valid_labels_directory = './C2_PCB/valid/labels/'
        test_labels_directory = './C2_PCB/test/labels/'
        source_images_directory = './DATA/PCB_DEFECTS_230728/'
        train_images_directory = './C2_PCB/train/images/'
        valid_images_directory = './C2_PCB/valid/images/'
        test_images_directory = './C2_PCB/test/images/'

    shutil_labels(train_index_labels, source_labels_directory, train_labels_directory)
    shutil_labels(valid_index_labels, source_labels_directory, valid_labels_directory)
    shutil_labels(test_index_labels, source_labels_directory, test_labels_directory)
    shutil_images(train_index_images, source_images_directory, train_images_directory)
    shutil_images(valid_index_images, source_images_directory, valid_images_directory)
    shutil_images(test_index_images, source_images_directory, test_images_directory)

# %%
if __name__ == "__main__":
    print(get_files_count("./C1_PCB/train/images/"), get_files_count("./C1_PCB/train/labels/"), end = ' ')
    print(get_files_count("./C1_PCB/valid/images/"), get_files_count("./C1_PCB/valid/labels/"), end = ' ')
    print(get_files_count("./C1_PCB/test/images/"), get_files_count("./C1_PCB/test/labels/"))
    
    print(get_files_count("./C2_PCB/train/images/"), get_files_count("./C2_PCB/train/labels/"), end = ' ')
    print(get_files_count("./C2_PCB/valid/images/"), get_files_count("./C2_PCB/valid/labels/"), end = ' ')
    print(get_files_count("./C2_PCB/test/images/"), get_files_count("./C2_PCB/test/labels/"))
# Out:
# 174 174 44 44 49 49
# 174 174 44 44 49 49

# %% [markdown]
# # Image Classification에 사용될 데이터 셋 생성
# - *기존 PCB, C1_PCB, C2_PCB에 GOODPCB 포함*
# - PCB_CLF (중앙집중형 Image classification에 사용)
# - PCB_C1_CLF (Client 1 Image classification에 사용)
# - PCB_C2_CLF (Client 2 Image classification에 사용)

# %%
goodpcb_files = []

path_an = f"./DATA/GOODPCB"
for path, subdirs, files in os.walk(path_an):
#     print([path, subdirs, files])
    for name in files:
        goodpcb_files.append(os.path.join('GOODPCB', name))
        
print(len(goodpcb_files))
# Out:
# 90

# %%
X_train, X_test = train_test_split(goodpcb_files, test_size = 0.1, random_state=1234)

# %%
print(len(X_train), len(X_test))
# Out:
# 81 9

# %% [markdown]
# ## PCB_CLF 생성

# %%
remove_directory('./PCB_CLF/train')
remove_directory('./PCB_CLF/test')
create_directory('./PCB_CLF/train')
create_directory('./PCB_CLF/test')
# Out:
# Removed directory: ./PCB_CLF/train
# Removed directory: ./PCB_CLF/test
# Created directory: ./PCB_CLF/train
# Created directory: ./PCB_CLF/test

# %%
source_directories = ['./PCB/train/images', './PCB/valid/images', './PCB/test/images']
dest_directories = ['./PCB_CLF/train', './PCB_CLF/train', './PCB_CLF/test']

for source_dir, dest_dir in zip(source_directories, dest_directories):
    # source 디렉토리의 모든 파일을 dest 디렉토리로 복사
    for filename in os.listdir(source_dir):
        if filename.endswith('.png'):
            source_file = os.path.join(source_dir, filename)
            dest_file = os.path.join(dest_dir, filename)
            shutil.copy(source_file, dest_file)

# %%
train_index = X_train
test_index = X_test

train_index_images = np.array([filename for filename in train_index])
test_index_images = np.array([filename for filename in test_index])


source_images_directory = './DATA/'
# goodpcb image C1_PCB과 C2_PCB에 분할

train_images_directory = './PCB_CLF/train/'
test_images_directory = './PCB_CLF/test/'

shutil_images(train_index_images, source_images_directory, train_images_directory)
shutil_images(test_index_images, source_images_directory, test_images_directory)

# %%
if __name__ == "__main__":
    print(get_files_count("./PCB_CLF/train/"), end = ' ')
    print(get_files_count("./PCB_CLF/test/"))
# Out:
# 517 58

# %% [markdown]
# ## C1_PCB_CLF, C2_PCB_CLF 생성

# %%
# test set이 주어진다면 위 행 삭제 후 아래 주석행 실행
# C1_files, C2_files = train_test_split(goodpcb_files, test_size = 0.5, random_state=1234)
C1_files, C2_files = train_test_split(X_train, test_size = 0.5, random_state=1234)

# %%
print(len(C1_files), len(C2_files))
# Out:
# 40 41

# %%
for client in ['C1_PCB_CLF', 'C2_PCB_CLF']:
    # 디렉토리 삭제 및 생성
    remove_directory(f'./{client}/train')
    remove_directory(f'./{client}/test')
    create_directory(f'./{client}/train')
    create_directory(f'./{client}/test')
# Out:
# Removed directory: ./C1_PCB_CLF/train
# Removed directory: ./C1_PCB_CLF/test
# Created directory: ./C1_PCB_CLF/train
# Created directory: ./C1_PCB_CLF/test
# Removed directory: ./C2_PCB_CLF/train
# Removed directory: ./C2_PCB_CLF/test
# Created directory: ./C2_PCB_CLF/train
# Created directory: ./C2_PCB_CLF/test

# %%
source_directories = ['./C1_PCB/train/images', './C1_PCB/valid/images', './C2_PCB/train/images', './C2_PCB/valid/images', './C1_PCB/test/images', './C2_PCB/test/images']
dest_directories = ['./C1_PCB_CLF/train', './C1_PCB_CLF/train', './C2_PCB_CLF/train', './C2_PCB_CLF/train', './C1_PCB_CLF/test', './C2_PCB_CLF/test']

for source_dir, dest_dir in zip(source_directories, dest_directories):
    # source 디렉토리의 모든 파일을 dest 디렉토리로 복사
    for filename in os.listdir(source_dir):
        if filename.endswith('.png'):
            source_file = os.path.join(source_dir, filename)
            dest_file = os.path.join(dest_dir, filename)
            shutil.copy(source_file, dest_file)

# %%
for idx, files in enumerate([C1_files, C2_files]):

    train_index = files
    test_index = X_test
#     print(len(train_index), len(valid_index), len(test_index))

    train_index_images = np.array([filename for filename in train_index])
    test_index_images = np.array([filename for filename in test_index])
    
    
    source_images_directory = './DATA/'
    # goodpcb image C1_PCB과 C2_PCB에 분할
    if idx == 0:
        train_images_directory = './C1_PCB_CLF/train/'
        test_images_directory = './C1_PCB_CLF/test/'

    else:
        train_images_directory = './C2_PCB_CLF/train/'
        test_images_directory = './C2_PCB_CLF/test/'
    
    shutil_images(train_index_images, source_images_directory, train_images_directory)
    shutil_images(test_index_images, source_images_directory, test_images_directory)

# %%
if __name__ == "__main__":
    
    
    print(get_files_count("./C1_PCB_CLF/train/"), end = ' ')
    print(get_files_count("./C1_PCB_CLF/test/"))
    
    print(get_files_count("./C2_PCB_CLF/train/"), end =' ')
    print(get_files_count("./C2_PCB_CLF/test/"))
# Out:
# 258 58
# 259 58

# %%
# remove_directory(f'./C1_PCB/dataset/')
# remove_directory(f'./C2_PCB/dataset/')

# %%
if __name__ == "__main__":
    print(get_files_count("./PCB_CLF/train/"), end = ' ')
    print(get_files_count("./PCB_CLF/test/"))
    
    print(get_files_count("./C1_PCB_CLF/train/"), end = ' ')
    print(get_files_count("./C1_PCB_CLF/test/"))
    
    print(get_files_count("./C2_PCB_CLF/train/"), end =' ')
    print(get_files_count("./C2_PCB_CLF/test/"))

    print(get_files_count("./PCB/train/images/"), get_files_count("./PCB/train/labels/"), end = ' ')
    print(get_files_count("./PCB/valid/images/"), get_files_count("./PCB/valid/labels/"), end = ' ')
    print(get_files_count("./PCB/test/images/"), get_files_count("./PCB/test/labels/"))
    
    print(get_files_count("./C1_PCB/train/images/"), get_files_count("./C1_PCB/train/labels/"), end = ' ')
    print(get_files_count("./C1_PCB/valid/images/"), get_files_count("./C1_PCB/valid/labels/"), end = ' ')
    print(get_files_count("./C1_PCB/test/images/"), get_files_count("./C1_PCB/test/labels/"))
    
    print(get_files_count("./C2_PCB/train/images/"), get_files_count("./C2_PCB/train/labels/"), end = ' ')
    print(get_files_count("./C2_PCB/valid/images/"), get_files_count("./C2_PCB/valid/labels/"), end = ' ')
    print(get_files_count("./C2_PCB/test/images/"), get_files_count("./C2_PCB/test/labels/"))
# Out:
# 517 58
# 258 58
# 259 58
# 348 348 88 88 49 49
# 174 174 44 44 49 49
# 174 174 44 44 49 49

# %% [markdown]
# # 라벨 개수 확인

# %%
# 라벨 개수
def label_counts(dir):
    # 경로 설정
    label_dir = dir
    file_pattern = "*.txt"

    # 각 숫자별 이름을 저장하는 딕셔너리 초기화
    number_names = {
        0: 'SCRATCH_1',
        1: 'DELAMINATION',
        2: 'POP_CORN_1',
        3: 'POP_CORN_2',
        4: 'others',
        5: 'others',
        6: 'others',
        7: 'others',
        8: 'others'
    }

    # 각 숫자별 개수를 저장할 딕셔너리 초기화
    number_counts = defaultdict(int)

    # 지정된 디렉토리에서 모든 txt 파일 찾기
    file_paths = glob.glob(os.path.join(label_dir, file_pattern))

    # 각 파일을 읽어서 첫 번째 숫자 개수 세기
    for file_path in file_paths:
        with open(file_path, 'r') as file:
            lines = file.readlines()
            for line in lines:
                parts = line.split()
                if parts:  # 비어있지 않은 줄만 처리
                    try:
                        number = int(float(parts[0]))  # 소수점 이하를 버리고 정수로 변환
                        if 0 <= number <= len(number_names):  # 0부터 5 사이의 숫자만 고려
                            number_counts[number] += 1
                    except ValueError:
                        pass

    # 숫자별 개수를 정렬하여 출력
    sorted_counts = sorted(number_counts.items(), key=lambda x: x[0])
    for number, count in sorted_counts:
        name = number_names[number]
        print(f"{name}: {count}개")

    # 총계 계산 및 출력
    total_count = sum(count for _, count in sorted_counts)
    print(f"총계: {total_count}개")

# %%
print('Train')
label_counts("./PCB/train/labels/")
print('\nValid')
label_counts("./PCB/valid/labels/")
print('\nTest')
label_counts("./PCB/test/labels/")
# Out:
# Train
# SCRATCH_1: 749개
# DELAMINATION: 130개
# POP_CORN_1: 364개
# POP_CORN_2: 30개
# 총계: 1273개
#
# Valid
# SCRATCH_1: 144개
# DELAMINATION: 33개
# POP_CORN_1: 92개
# POP_CORN_2: 5개
# 총계: 274개
#
# Test
# SCRATCH_1: 101개
# DELAMINATION: 22개
# POP_CORN_1: 49개
# POP_CORN_2: 5개
# 총계: 177개

# %%
print('Train')
label_counts("./C1_PCB/train/labels/")
print('\nValid')
label_counts("./C1_PCB/valid/labels/")
print('\nTest')
label_counts("./C1_PCB/test/labels/")
# Out:
# Train
# SCRATCH_1: 372개
# DELAMINATION: 75개
# POP_CORN_1: 188개
# POP_CORN_2: 9개
# 총계: 644개
#
# Valid
# SCRATCH_1: 103개
# DELAMINATION: 15개
# POP_CORN_1: 57개
# POP_CORN_2: 6개
# 총계: 181개
#
# Test
# SCRATCH_1: 101개
# DELAMINATION: 22개
# POP_CORN_1: 49개
# POP_CORN_2: 5개
# 총계: 177개

# %%
print('Train')
label_counts("./C2_PCB/train/labels/")
print('\nValid')
label_counts("./C2_PCB/valid/labels/")
print('\nTest')
label_counts("./C2_PCB/test/labels/")
# Out:
# Train
# SCRATCH_1: 302개
# DELAMINATION: 54개
# POP_CORN_1: 175개
# POP_CORN_2: 17개
# 총계: 548개
#
# Valid
# SCRATCH_1: 116개
# DELAMINATION: 19개
# POP_CORN_1: 36개
# POP_CORN_2: 3개
# 총계: 174개
#
# Test
# SCRATCH_1: 101개
# DELAMINATION: 22개
# POP_CORN_1: 49개
# POP_CORN_2: 5개
# 총계: 177개

# %% [markdown]
# # PCB_CLF GOODPCB 증강

# %%
# 입력 폴더와 출력 폴더를 동일하게 설정합니다.
input_output_folder = ["./PCB_CLF/train/", "./C1_PCB_CLF/train/", "./C2_PCB_CLF/train/"]

transform = A.Compose([
    A.Resize(416, 416),
    A.RandomCrop(width=256, height=256, p=1),
    A.RandomRotate90(p=0.5),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.Resize(416, 416),

])

for i_o_folder in input_output_folder:
    # 입력 폴더의 이미지 파일을 반복하며 증강 및 저장합니다.
    for filename in os.listdir(i_o_folder):
        if filename.endswith(".png") and "GOODPCB" in filename:
            image_path = os.path.join(i_o_folder, filename)
            image = cv2.imread(image_path)

            # 이미지를 5회 증강합니다.
            for i in range(5):
                augmented = transform(image=image)
                augmented_image = augmented["image"]

                # 저장할 파일 이름을 생성합니다.
                new_filename = filename.replace(".png", f"_AUG_{i}.png")
                output_path = os.path.join(i_o_folder, new_filename)

                # 이미지를 덮어쓰기 형식으로 저장합니다.
                cv2.imwrite(output_path, augmented_image)
                print(f"저장 완료: {output_path}")
# Out:
# 저장 완료: ./PCB_CLF/train/GOODPCB_56_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_56_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_56_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_56_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_56_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_64_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_64_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_64_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_64_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_64_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_74_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_74_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_74_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_74_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_74_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_16_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_16_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_16_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_16_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_16_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_14_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_14_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_14_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_14_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_14_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_58_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_58_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_58_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_58_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_58_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_60_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_60_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_60_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_60_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_60_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_15_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_15_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_15_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_15_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_15_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_81_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_81_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_81_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_81_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_81_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_8_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_8_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_8_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_8_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_8_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_36_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_36_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_36_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_36_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_36_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_35_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_35_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_35_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_35_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_35_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_41_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_41_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_41_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_41_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_41_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_55_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_55_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_55_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_55_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_55_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_63_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_63_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_63_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_63_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_63_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_44_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_44_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_44_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_44_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_44_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_65_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_65_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_65_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_65_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_65_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_32_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_32_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_32_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_32_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_32_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_85_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_85_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_85_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_85_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_85_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_91_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_91_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_91_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_91_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_91_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_79_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_79_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_79_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_79_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_79_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_71_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_71_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_71_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_71_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_71_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_6_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_6_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_6_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_6_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_6_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_11_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_11_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_11_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_11_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_11_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_69_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_69_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_69_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_69_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_69_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_5_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_5_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_5_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_5_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_5_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_83_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_83_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_83_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_83_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_83_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_20_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_20_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_20_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_20_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_20_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_61_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_61_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_61_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_61_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_61_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_22_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_22_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_22_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_22_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_22_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_12_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_12_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_12_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_12_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_12_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_68_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_68_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_68_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_68_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_68_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_34_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_34_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_34_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_34_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_34_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_3_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_3_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_3_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_3_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_3_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_38_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_38_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_38_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_38_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_38_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_59_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_59_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_59_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_59_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_59_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_73_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_73_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_73_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_73_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_73_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_89_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_89_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_89_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_89_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_89_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_13_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_13_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_13_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_13_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_13_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_84_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_84_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_84_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_84_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_84_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_7_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_7_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_7_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_7_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_7_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_70_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_70_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_70_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_70_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_70_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_1_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_1_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_1_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_1_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_1_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_50_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_50_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_50_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_50_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_50_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_54_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_54_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_54_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_54_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_54_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_37_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_37_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_37_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_37_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_37_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_17_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_17_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_17_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_17_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_17_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_76_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_76_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_76_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_76_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_76_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_88_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_88_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_88_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_88_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_88_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_26_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_26_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_26_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_26_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_26_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_82_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_82_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_82_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_82_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_82_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_92_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_92_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_92_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_92_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_92_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_45_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_45_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_45_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_45_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_45_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_52_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_52_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_52_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_52_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_52_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_86_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_86_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_86_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_86_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_86_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_23_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_23_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_23_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_23_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_23_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_31_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_31_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_31_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_31_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_31_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_10_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_10_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_10_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_10_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_10_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_4_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_4_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_4_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_4_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_4_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_51_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_51_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_51_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_51_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_51_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_48_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_48_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_48_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_48_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_48_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_47_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_47_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_47_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_47_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_47_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_19_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_19_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_19_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_19_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_19_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_87_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_87_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_87_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_87_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_87_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_24_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_24_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_24_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_24_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_24_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_80_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_80_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_80_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_80_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_80_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_33_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_33_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_33_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_33_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_33_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_2_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_2_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_2_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_2_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_2_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_62_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_62_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_62_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_62_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_62_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_39_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_39_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_39_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_39_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_39_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_77_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_77_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_77_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_77_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_77_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_30_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_30_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_30_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_30_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_30_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_67_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_67_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_67_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_67_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_67_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_28_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_28_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_28_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_28_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_28_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_27_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_27_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_27_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_27_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_27_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_75_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_75_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_75_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_75_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_75_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_29_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_29_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_29_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_29_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_29_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_21_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_21_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_21_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_21_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_21_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_25_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_25_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_25_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_25_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_25_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_53_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_53_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_53_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_53_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_53_AUG_4.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_42_AUG_0.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_42_AUG_1.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_42_AUG_2.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_42_AUG_3.png
# 저장 완료: ./PCB_CLF/train/GOODPCB_42_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_64_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_64_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_64_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_64_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_64_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_74_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_74_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_74_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_74_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_74_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_14_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_14_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_14_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_14_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_14_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_60_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_60_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_60_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_60_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_60_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_81_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_81_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_81_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_81_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_81_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_36_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_36_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_36_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_36_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_36_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_55_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_55_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_55_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_55_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_55_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_63_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_63_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_63_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_63_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_63_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_44_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_44_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_44_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_44_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_44_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_32_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_32_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_32_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_32_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_32_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_91_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_91_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_91_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_91_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_91_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_79_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_79_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_79_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_79_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_79_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_11_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_11_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_11_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_11_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_11_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_83_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_83_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_83_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_83_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_83_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_20_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_20_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_20_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_20_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_20_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_61_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_61_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_61_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_61_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_61_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_3_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_3_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_3_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_3_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_3_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_38_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_38_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_38_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_38_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_38_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_59_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_59_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_59_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_59_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_59_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_89_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_89_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_89_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_89_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_89_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_13_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_13_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_13_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_13_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_13_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_84_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_84_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_84_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_84_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_84_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_50_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_50_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_50_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_50_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_50_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_17_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_17_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_17_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_17_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_17_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_88_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_88_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_88_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_88_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_88_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_82_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_82_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_82_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_82_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_82_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_92_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_92_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_92_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_92_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_92_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_23_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_23_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_23_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_23_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_23_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_51_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_51_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_51_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_51_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_51_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_48_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_48_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_48_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_48_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_48_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_19_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_19_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_19_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_19_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_19_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_33_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_33_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_33_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_33_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_33_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_62_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_62_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_62_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_62_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_62_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_39_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_39_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_39_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_39_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_39_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_77_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_77_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_77_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_77_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_77_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_30_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_30_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_30_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_30_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_30_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_28_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_28_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_28_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_28_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_28_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_75_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_75_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_75_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_75_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_75_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_29_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_29_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_29_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_29_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_29_AUG_4.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_25_AUG_0.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_25_AUG_1.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_25_AUG_2.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_25_AUG_3.png
# 저장 완료: ./C1_PCB_CLF/train/GOODPCB_25_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_56_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_56_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_56_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_56_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_56_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_16_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_16_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_16_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_16_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_16_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_58_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_58_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_58_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_58_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_58_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_15_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_15_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_15_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_15_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_15_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_8_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_8_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_8_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_8_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_8_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_35_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_35_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_35_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_35_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_35_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_41_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_41_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_41_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_41_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_41_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_65_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_65_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_65_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_65_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_65_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_85_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_85_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_85_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_85_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_85_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_71_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_71_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_71_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_71_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_71_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_6_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_6_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_6_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_6_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_6_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_69_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_69_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_69_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_69_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_69_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_5_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_5_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_5_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_5_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_5_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_22_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_22_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_22_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_22_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_22_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_12_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_12_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_12_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_12_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_12_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_68_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_68_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_68_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_68_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_68_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_34_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_34_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_34_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_34_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_34_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_73_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_73_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_73_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_73_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_73_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_7_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_7_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_7_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_7_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_7_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_70_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_70_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_70_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_70_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_70_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_1_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_1_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_1_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_1_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_1_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_54_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_54_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_54_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_54_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_54_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_37_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_37_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_37_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_37_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_37_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_76_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_76_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_76_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_76_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_76_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_26_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_26_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_26_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_26_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_26_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_45_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_45_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_45_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_45_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_45_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_52_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_52_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_52_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_52_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_52_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_86_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_86_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_86_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_86_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_86_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_31_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_31_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_31_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_31_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_31_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_10_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_10_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_10_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_10_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_10_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_4_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_4_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_4_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_4_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_4_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_47_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_47_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_47_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_47_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_47_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_87_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_87_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_87_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_87_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_87_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_24_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_24_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_24_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_24_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_24_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_80_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_80_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_80_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_80_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_80_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_2_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_2_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_2_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_2_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_2_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_67_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_67_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_67_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_67_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_67_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_27_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_27_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_27_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_27_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_27_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_21_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_21_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_21_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_21_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_21_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_53_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_53_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_53_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_53_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_53_AUG_4.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_42_AUG_0.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_42_AUG_1.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_42_AUG_2.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_42_AUG_3.png
# 저장 완료: ./C2_PCB_CLF/train/GOODPCB_42_AUG_4.png

# %%
print(get_files_count("./PCB_CLF/train/"))
print(get_files_count("./C1_PCB_CLF/train/"))
print(get_files_count("./C2_PCB_CLF/train/"))
# Out:
# 922
# 458
# 464

# %%
import os
import matplotlib.pyplot as plt

# 디렉토리 경로 설정
directory = ["./PCB_CLF/train/", "./C1_PCB_CLF/train/", "./C2_PCB_CLF/train/"]

for direc in directory:
    # 디렉토리 내의 파일 목록 가져오기
    file_list = os.listdir(direc)

    # "GOODPCB" 이름이 포함된 파일 개수 세기
    goodpcb_file_count = sum(1 for file in file_list if "GOODPCB" in file)

    # 그 외 파일 개수 계산
    total_file_count = len(file_list) - goodpcb_file_count

    # 그래프 그리기
    labels = ['GOODPCB', 'Other']
    file_counts = [goodpcb_file_count, total_file_count]
    print(labels, file_counts)
# Out:
# ['GOODPCB', 'Other'] [486, 436]
# ['GOODPCB', 'Other'] [240, 218]
# ['GOODPCB', 'Other'] [246, 218]
