# %% [markdown]
# # Client 1 Object Detection

# %%
# 최적의 모델을 얻고 싶을 경우, 세션 재시작 후 CPU 코어 8개로 설정.
import os
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

# %%
# !pip install -r ./requirements.txt.client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: Flask in /usr/local/lib/python3.8/dist-packages (from -r ./requirements.txt.client (line 1)) (1.1.4)
# Requirement already satisfied: python-engineio in /home/work/.local/lib/python3.8/site-packages (from -r ./requirements.txt.client (line 2)) (4.8.0)
# Requirement already satisfied: python-socketio in /home/work/.local/lib/python3.8/site-packages (from -r ./requirements.txt.client (line 3)) (5.10.0)
# Requirement already satisfied: Flask-socketIO in /home/work/.local/lib/python3.8/site-packages (from -r ./requirements.txt.client (line 4)) (5.3.6)
# Requirement already satisfied: opencv-python in /home/work/.local/lib/python3.8/site-packages (from -r ./requirements.txt.client (line 5)) (4.8.1.78)
# Requirement already satisfied: torchvision in /home/work/.local/lib/python3.8/site-packages (from -r ./requirements.txt.client (line 6)) (0.16.0)
# Requirement already satisfied: fake-useragent in /home/work/.local/lib/python3.8/site-packages (from -r ./requirements.txt.client (line 7)) (1.3.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.8/dist-packages (from -r ./requirements.txt.client (line 8)) (0.3.1.1)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.8/dist-packages (from Flask->-r ./requirements.txt.client (line 1)) (7.1.2)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.8/dist-packages (from Flask->-r ./requirements.txt.client (line 1)) (1.0.0)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.8/dist-packages (from Flask->-r ./requirements.txt.client (line 1)) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.8/dist-packages (from Flask->-r ./requirements.txt.client (line 1)) (2.11.3)
# Requirement already satisfied: simple-websocket>=0.10.0 in /home/work/.local/lib/python3.8/site-packages (from python-engineio->-r ./requirements.txt.client (line 2)) (1.0.0)
# Requirement already satisfied: bidict>=0.21.0 in /home/work/.local/lib/python3.8/site-packages (from python-socketio->-r ./requirements.txt.client (line 3)) (0.22.1)
# Requirement already satisfied: numpy>=1.17.0 in /home/work/.local/lib/python3.8/site-packages (from opencv-python->-r ./requirements.txt.client (line 5)) (1.22.4)
# Requirement already satisfied: torch==2.1.0 in /home/work/.local/lib/python3.8/site-packages (from torchvision->-r ./requirements.txt.client (line 6)) (2.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/work/.local/lib/python3.8/site-packages (from torchvision->-r ./requirements.txt.client (line 6)) (10.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchvision->-r ./requirements.txt.client (line 6)) (2.24.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.8/dist-packages (from torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (2021.6.0)
# Requirement already satisfied: typing-extensions in /home/work/.local/lib/python3.8/site-packages (from torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (4.8.0)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/work/.local/lib/python3.8/site-packages (from torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (11.0.2.54)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/work/.local/lib/python3.8/site-packages (from torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/work/.local/lib/python3.8/site-packages (from torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (12.1.3.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/work/.local/lib/python3.8/site-packages (from torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (2.18.1)
# Requirement already satisfied: triton==2.1.0 in /home/work/.local/lib/python3.8/site-packages (from torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (2.1.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/work/.local/lib/python3.8/site-packages (from torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/work/.local/lib/python3.8/site-packages (from torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (12.1.105)
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (from torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (2.5.1)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/work/.local/lib/python3.8/site-packages (from torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (12.1.0.106)
# Requirement already satisfied: sympy in /home/work/.local/lib/python3.8/site-packages (from torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (1.12)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/work/.local/lib/python3.8/site-packages (from torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (11.4.5.107)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/work/.local/lib/python3.8/site-packages (from torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (10.3.2.106)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/work/.local/lib/python3.8/site-packages (from torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (8.9.2.26)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/work/.local/lib/python3.8/site-packages (from torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (12.1.105)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (3.0.12)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/work/.local/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (12.2.140)
# Requirement already satisfied: importlib-resources>=5.0 in /usr/local/lib/python3.8/dist-packages (from fake-useragent->-r ./requirements.txt.client (line 7)) (5.1.4)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=5.0->fake-useragent->-r ./requirements.txt.client (line 7)) (3.4.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from Jinja2<3.0,>=2.10.1->Flask->-r ./requirements.txt.client (line 1)) (2.0.1)
# Requirement already satisfied: wsproto in /home/work/.local/lib/python3.8/site-packages (from simple-websocket>=0.10.0->python-engineio->-r ./requirements.txt.client (line 2)) (1.2.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision->-r ./requirements.txt.client (line 6)) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision->-r ./requirements.txt.client (line 6)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision->-r ./requirements.txt.client (line 6)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision->-r ./requirements.txt.client (line 6)) (2021.5.30)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.8/dist-packages (from networkx->torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (4.4.2)
# Requirement already satisfied: mpmath>=0.19 in /home/work/.local/lib/python3.8/site-packages (from sympy->torch==2.1.0->torchvision->-r ./requirements.txt.client (line 6)) (1.3.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /home/work/.local/lib/python3.8/site-packages (from wsproto->simple-websocket>=0.10.0->python-engineio->-r ./requirements.txt.client (line 2)) (0.14.0)
# WARNING: You are using pip version 21.3.1; however, version 23.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install pybboxes albumentations==1.3.0 --upgrade typing-extensions torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: pybboxes in /home/work/.local/lib/python3.8/site-packages (0.1.6)
# Requirement already satisfied: albumentations==1.3.0 in /home/work/.local/lib/python3.8/site-packages (1.3.0)
# Requirement already satisfied: typing-extensions in /home/work/.local/lib/python3.8/site-packages (4.8.0)
# Requirement already satisfied: torch in /home/work/.local/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from albumentations==1.3.0) (5.3.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from albumentations==1.3.0) (1.7.2)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.8/dist-packages (from albumentations==1.3.0) (4.5.4.58)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.8/dist-packages (from albumentations==1.3.0) (0.16.2)
# Requirement already satisfied: numpy>=1.11.1 in /home/work/.local/lib/python3.8/site-packages (from albumentations==1.3.0) (1.22.4)
# Requirement already satisfied: qudida>=0.0.4 in /home/work/.local/lib/python3.8/site-packages (from albumentations==1.3.0) (0.0.4)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/work/.local/lib/python3.8/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/work/.local/lib/python3.8/site-packages (from torch) (12.1.105)
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (from torch) (2.5.1)
# Requirement already satisfied: sympy in /home/work/.local/lib/python3.8/site-packages (from torch) (1.12)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/work/.local/lib/python3.8/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/work/.local/lib/python3.8/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/work/.local/lib/python3.8/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/work/.local/lib/python3.8/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/work/.local/lib/python3.8/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.8/dist-packages (from torch) (2021.6.0)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/work/.local/lib/python3.8/site-packages (from torch) (2.18.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/work/.local/lib/python3.8/site-packages (from torch) (12.1.105)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from torch) (2.11.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from torch) (3.0.12)
# Requirement already satisfied: triton==2.1.0 in /home/work/.local/lib/python3.8/site-packages (from torch) (2.1.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/work/.local/lib/python3.8/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/work/.local/lib/python3.8/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/work/.local/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.2.140)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.8/dist-packages (from qudida>=0.0.4->albumentations==1.3.0) (0.24.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (2.9.0)
# Requirement already satisfied: pillow>=4.3.0 in /home/work/.local/lib/python3.8/site-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (10.1.0)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (3.4.2)
# Requirement already satisfied: PyWavelets>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (1.1.1)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.8/dist-packages (from networkx->torch) (4.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->torch) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /home/work/.local/lib/python3.8/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==1.3.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==1.3.0) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==1.3.0) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.7 in /home/work/.local/lib/python3.8/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==1.3.0) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations==1.3.0) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations==1.3.0) (0.14.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from cycler>=0.10->matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==1.3.0) (1.15.0)
# WARNING: You are using pip version 21.3.1; however, version 23.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import albumentations as A
from augmentation import get_bboxes_list, apply_aug
import yaml

# %%
import shutil
import zipfile
import numpy as np
import pandas as pd
from PIL import Image
import PIL
import json
import sys
import shutil
from distutils.dir_util import copy_tree
# import imagesize
# import ptitprince as pt
from shutil import copyfile
import time
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.patches as mpatches
import seaborn as sns
import re
import xml.etree.ElementTree as ET
from sklearn.model_selection import train_test_split
import random
import torch
from tqdm.notebook import tqdm
import cv2
from collections import defaultdict
import glob

# %%
def seed_everything(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = False
    torch.use_deterministic_algorithms(True)
    os.environ["PYTHONHASHSEED"] = str(seed)
    os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"
seed_everything()

# %%
client = 'C1_PCB' # if client 1
class_name = ['SCRATCH', 'DELAMINATION', 'POP_CORN_1', 'POP_CORN_2'] # BOXING_TXT_1013

# %% [markdown]
# ## 데이터 증강

# %%
# # 데이터 증강했으면 재증강하지 않는다.
# # YAML 데이터 생성
# data = {
#     "inp_img_pth": f"./{client}/train/images/",
#     "inp_lab_pth": f"./{client}/train/labels/",
#     "out_img_pth": f"./{client}/train/images/",
#     "out_lab_pth": f"./{client}/train/labels/",
#     "transformed_file_name": "AUG",
#     "CLASSES": class_name
# }

# # YAML 파일에 데이터 쓰기
# with open(f"./{client}/train_contants.yaml", 'w') as yaml_file:
#     yaml.dump(data, yaml_file)

# with open(f"./{client}/train_contants.yaml", 'r') as stream:
#     CONSTANTS = yaml.safe_load(stream)

# imgs = os.listdir(CONSTANTS["inp_img_pth"])
# for img_file in tqdm(imgs):
#     file_name = img_file[:-4]
#     if 'ipynb_checkpo' in file_name:
#         continue
#     image = cv2.imread(os.path.join(CONSTANTS["inp_img_pth"], img_file))
#     lab_pth = os.path.join(CONSTANTS["inp_lab_pth"], file_name + '.txt')
#     album_bboxes = get_bboxes_list(lab_pth, CONSTANTS['CLASSES'])
#     print(file_name)
#     # x번의 데이터 증강을 수행하고 각각의 결과를 저장 range(1, x) <- 여기를 변경
#     for i in range(1, 5):
#         aug_file_name = f"{file_name}_AUG_{i}"
#         try:
#             apply_aug(image, album_bboxes, CONSTANTS["out_lab_pth"], CONSTANTS["out_img_pth"], aug_file_name, CONSTANTS['CLASSES'])
#         except Exception as e:
#             print(f"An error occurred for {aug_file_name}: {str(e)}")
#             continue  # 에러 발생 시 해당 부분을 건너뛰고 계속 진행

# %% [markdown]
# ## YAML 파일 생성

# %%
# yaml 파일 생성
data = { 'train' : os.getcwd() + f'/{client}/train/images',
         'val' : os.getcwd() + f'/{client}/valid/images/',
         'test' : os.getcwd() + f'/{client}/test/images',
         'names' : class_name,
         'nc' : len(class_name) }

with open(f'./{client}/PCB.yaml', 'w') as f:
    yaml.dump(data, f)

with open(f'./{client}/PCB.yaml', 'r') as f:
    pcb_yaml = yaml.safe_load(f)
    display(pcb_yaml)
# Out:
# {'names': ['SCRATCH', 'DELAMINATION', 'POP_CORN_1', 'POP_CORN_2'],
#  'nc': 4,
#  'test': '/home/work/KISTI_PCB2/C1_PCB/test/images',
#  'train': '/home/work/KISTI_PCB2/C1_PCB/train/images',
#  'val': '/home/work/KISTI_PCB2/C1_PCB/valid/images/'}

# %%
# !cat ./{client}/PCB.yaml
# Out:
# names:
# - SCRATCH
# - DELAMINATION
# - POP_CORN_1
# - POP_CORN_2
# nc: 4
# test: /home/work/KISTI_PCB2/C1_PCB/test/images
# train: /home/work/KISTI_PCB2/C1_PCB/train/images
# val: /home/work/KISTI_PCB2/C1_PCB/valid/images/

# %% [markdown]
# ## Yolov5 Train

# %%
if os.getcwd() != '/home/work/KISTI_PCB2/yolov5':
    os.chdir('./yolov5')
os.getcwd()
# Out:
# '/home/work/KISTI_PCB2/yolov5'

# %%
# !python train.py --data "/home/work/KISTI_PCB2/{client}/PCB.yaml" \
    --epochs 300 \
    --patience 15 \
    --batch 32 \
    --imgsz 640 \
    --weights 'yolov5n.pt' \
    --name '{client}_results' \
    --exist-ok
# Out:
# train: weights=yolov5n.pt, cfg=, data=/home/work/KISTI_PCB2/C1_PCB/PCB.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=C1_PCB_results, exist_ok=True, quad=False, cos_lr=False, label_smoothing=0.0, patience=15, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 3 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.8.10 torch-2.1.0+cu121 CUDA:0 (Quadro RTX 8000, 48593MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=4
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1760  models.common.Conv                      [3, 16, 6, 2, 2]
#   1                -1  1      4672  models.common.Conv                      [16, 32, 3, 2]
#   2                -1  1      4800  models.common.C3                        [32, 32, 1]
#   3                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   4                -1  2     29184  models.common.C3                        [64, 64, 2]
#   5                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   6                -1  3    156928  models.common.C3                        [128, 128, 3]
#   7                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   8                -1  1    296448  models.common.C3                        [256, 256, 1]
#   9                -1  1    164608  models.common.SPPF                      [256, 256, 5]
#  10                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  14                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     22912  models.common.C3                        [128, 64, 1, False]
#  18                -1  1     36992  models.common.Conv                      [64, 64, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1     74496  models.common.C3                        [128, 128, 1, False]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  24      [17, 20, 23]  1     12177  models.yolo.Detect                      [4, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [64, 128, 256]]
# Model summary: 214 layers, 1769329 parameters, 1769329 gradients, 4.2 GFLOPs
#
# Transferred 343/349 items from yolov5n.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: float division by zero
# train: Scanning /home/work/KISTI_PCB2/C1_PCB/train/labels.cache... 570 images, 2
# val: Scanning /home/work/KISTI_PCB2/C1_PCB/valid/labels.cache... 44 images, 0 ba
#
# AutoAnchor: 4.73 anchors/target, 0.998 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/C1_PCB_results/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/C1_PCB_results
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/299         4G     0.1255    0.02652     0.0464         80        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181    0.00024     0.0219   0.000154   2.86e-05
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/299         4G     0.1097    0.02561    0.03572         85        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181   0.000315     0.0658   0.000808   0.000172
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/299         4G    0.09726    0.03021    0.02712        109        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.752     0.0439    0.00449     0.0007
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/299         4G    0.09019    0.03064    0.02251        111        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.527      0.213     0.0157    0.00358
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/299         4G    0.08582    0.03228    0.01874        103        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181     0.0108      0.358      0.012    0.00237
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/299         4G    0.08367    0.02876    0.01725         99        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.306      0.135     0.0386      0.008
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/299         4G    0.08085    0.02987    0.01494         97        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.302      0.107     0.0276    0.00651
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/299         4G    0.07714    0.02972    0.01297         98        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.315       0.12      0.036      0.013
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/299         4G    0.07282     0.0284    0.01104        142        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.355      0.148     0.0609     0.0151
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/299         4G    0.07259    0.02791    0.01042        109        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.426      0.124      0.103     0.0238
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/299         4G    0.06992    0.02649   0.009808        104        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181       0.47      0.213      0.138     0.0362
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/299         4G    0.06918    0.02703   0.009532         76        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.436      0.266      0.156     0.0423
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/299         4G    0.06787    0.02677   0.008309        101        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.545      0.188      0.148     0.0461
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/299         4G     0.0674    0.02769   0.008605         85        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.486      0.237      0.183     0.0562
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/299         4G    0.06614    0.02651   0.007496        102        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.529      0.337       0.26     0.0824
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/299         4G    0.06467    0.02816    0.00646         95        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.493      0.239      0.185     0.0523
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/299         4G    0.06329    0.02722   0.006492         98        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.525      0.272      0.247     0.0722
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/299         4G    0.06346    0.02672   0.006175         89        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.578      0.298      0.347      0.104
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      18/299         4G    0.06239    0.02566   0.006207         91        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.485      0.252      0.309      0.108
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      19/299         4G    0.05978    0.02605   0.006267        100        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.673      0.234       0.31     0.0939
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      20/299         4G    0.06137     0.0262   0.005464         82        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.566      0.287       0.29     0.0911
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      21/299         4G    0.06018    0.02672   0.005489         74        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.632      0.374      0.367      0.121
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      22/299         4G     0.0586    0.02624    0.00567         89        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.558      0.314      0.322     0.0983
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      23/299         4G    0.05921    0.02631   0.006012         88        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.543      0.314      0.279      0.106
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      24/299         4G    0.06031    0.02703   0.004645        130        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.561      0.232      0.262      0.102
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      25/299         4G    0.05745     0.0256   0.004669         95        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.616      0.308      0.395      0.135
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      26/299         4G    0.05804    0.02589   0.004992         91        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.621      0.299      0.373      0.116
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      27/299         4G    0.05743    0.02561   0.004998         95        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.607      0.317      0.353       0.11
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      28/299         4G    0.05668    0.02406   0.004325        105        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.691      0.348      0.404      0.139
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      29/299         4G    0.05597    0.02403   0.004854        103        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.614      0.326      0.368      0.119
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      30/299         4G    0.05618    0.02486   0.003721         77        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.642       0.27      0.347      0.112
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      31/299         4G    0.05609    0.02434   0.003861        105        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181       0.71      0.325      0.392      0.142
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      32/299         4G    0.05604    0.02468   0.003921        142        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181       0.64      0.292      0.392      0.148
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      33/299         4G    0.05667    0.02441   0.004338         69        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.586      0.356      0.366      0.133
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      34/299         4G    0.05573    0.02545   0.004188         88        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.682       0.31       0.36      0.122
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      35/299         4G    0.05606    0.02233   0.003669        121        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.486      0.397      0.366      0.129
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      36/299         4G    0.05456    0.02277   0.003382         83        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.687      0.337      0.412       0.15
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      37/299         4G    0.05561    0.02477   0.003567        101        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.636      0.379       0.42      0.155
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      38/299         4G    0.05458    0.02528   0.003754        120        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.653      0.317      0.402      0.153
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      39/299         4G    0.05273    0.02281   0.003677         99        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.661      0.375      0.386      0.144
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      40/299         4G    0.05387    0.02388   0.003223        112        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.625      0.355      0.402       0.15
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      41/299         4G     0.0545    0.02311   0.003626         82        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.381      0.517      0.437      0.154
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      42/299         4G    0.05195      0.024   0.002907        109        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.683      0.376      0.444      0.156
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      43/299         4G    0.05204    0.02272   0.002946        133        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.753      0.334      0.449      0.164
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      44/299         4G    0.05316    0.02353   0.002871        138        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.623      0.367      0.434      0.162
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      45/299         4G    0.05239    0.02211   0.003463        101        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.606      0.388       0.38      0.127
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      46/299         4G    0.05273    0.02275    0.00365         71        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.648      0.365      0.421      0.172
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      47/299         4G    0.05231     0.0232   0.002979        106        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.704      0.389       0.43      0.163
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      48/299         4G    0.05284    0.02332    0.00301        115        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.534       0.41       0.43      0.172
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      49/299         4G    0.05178    0.02317   0.003263        108        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.719      0.395      0.436      0.167
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      50/299         4G    0.05081     0.0233   0.003298        108        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.395      0.482      0.414      0.147
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      51/299         4G    0.05163    0.02368   0.003583        110        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.748      0.372      0.461       0.16
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      52/299         4G    0.05015    0.02285     0.0029         89        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.738      0.373      0.415       0.14
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      53/299         4G     0.0508    0.02236   0.003198         85        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.718      0.275      0.358      0.124
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      54/299         4G    0.05101    0.02305   0.003313        111        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.774      0.286      0.392      0.137
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      55/299         4G    0.05199    0.02266   0.002482         86        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181       0.64      0.394      0.393      0.129
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      56/299         4G    0.04859    0.02245   0.002881         63        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.698      0.346        0.4      0.129
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      57/299         4G    0.05261    0.02141   0.003109        115        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.734       0.26      0.354      0.125
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      58/299         4G    0.04969    0.02177   0.002648        102        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.654      0.333      0.387      0.122
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      59/299         4G    0.04959    0.02313   0.002294         87        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.476      0.428      0.423       0.14
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      60/299         4G    0.04863    0.02174   0.003044         97        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.482      0.413      0.394      0.143
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      61/299         4G    0.04844    0.02196   0.002713        138        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.485      0.375      0.381      0.136
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      62/299         4G    0.04895    0.02205   0.002675        113        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.538      0.402      0.389      0.149
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      63/299         4G    0.04873    0.02179   0.002368         84        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.406      0.428      0.375       0.13
# Stopping training early as no improvement observed in last 15 epochs. Best results observed at epoch 48, best model saved as best.pt.
# To update EarlyStopping(patience=15) pass a new patience value, i.e. `python train.py --patience 300` or use `--patience 0` to disable EarlyStopping.
#
# 64 epochs completed in 0.080 hours.
# Optimizer stripped from runs/train/C1_PCB_results/weights/last.pt, 3.9MB
# Optimizer stripped from runs/train/C1_PCB_results/weights/best.pt, 3.9MB
#
# Validating runs/train/C1_PCB_results/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 1764577 parameters, 0 gradients, 4.1 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.534       0.41       0.43      0.172
#                SCRATCH         44        103      0.433      0.544      0.546      0.163
#           DELAMINATION         44         15      0.331      0.533      0.343      0.095
#             POP_CORN_1         44         57      0.372      0.561       0.49      0.182
#             POP_CORN_2         44          6          1          0      0.342      0.248
# Results saved to runs/train/C1_PCB_results

# %% [markdown]
# ## Test Yolo(Client 1 Centralized)

# %%
# !python val.py --data "/home/work/KISTI_PCB2/{client}/PCB.yaml" --weights "/home/work/KISTI_PCB2/yolov5/runs/train/{client}_train_results/weights/best.pt" --task 'test' --name '{client}_result_final(central)' --exist-ok

# %% [markdown]
# # Do Federated Learning (Client 1)

# %%
from fedClient import *

torch.hub.load('ultralytics/yolov5', 'yolov5n')
token = generate_token('http://fl-aggregator.kro.kr', capacity = 2)
# Out:
# Using cache found in /home/work/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-10-19 Python-3.8.10 torch-2.1.0+cu121 CUDA:0 (Quadro RTX 8000, 48593MiB)
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients, 4.5 GFLOPs
# Adding AutoShape...

# %%
token
# Out:
# 'tGD6z2Yw7yqiY1g6'

# %%
num_round = 15
for n in range(1, num_round+1):
        print(f'Round {n} Start \n')

        # n-1 round 모델 기반 Client 학습 모델 불러오기
        with open(f"/home/work/KISTI_PCB2/yolov5/runs/train/{client}_results/weights/best.pt", "rb") as f:
            model_bytes = f.read()
        
        # n round에서의 연합 학습
        federate('http://fl-aggregator.kro.kr', token = token, model_bytes = str(model_bytes), round = n)
         
        # n round client 학습
        if n != num_round:
            # !python train.py --data "/home/work/KISTI_PCB2/{client}/PCB.yaml" \
                --epochs 300 \
                --patience 15 \
                --batch 32 \
                --imgsz 640 \
                --weights "model{n}_{token}.pt" \
                --name '{client}_results' \
                --exist-ok
# Out:
# Round 1 Start
#
# Connected to Flask-SocketIO server
# packet queue is empty, aborting
# Using cache found in /home/work/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-10-19 Python-3.8.10 torch-2.1.0+cu121 CUDA:0 (Quadro RTX 8000, 48593MiB)
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients, 4.5 GFLOPs
# Adding AutoShape...
# train: weights=model1_tGD6z2Yw7yqiY1g6.pt, cfg=, data=/home/work/KISTI_PCB2/C1_PCB/PCB.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=C1_PCB_results, exist_ok=True, quad=False, cos_lr=False, label_smoothing=0.0, patience=15, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 3 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.8.10 torch-2.1.0+cu121 CUDA:0 (Quadro RTX 8000, 48593MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1760  models.common.Conv                      [3, 16, 6, 2, 2]
#   1                -1  1      4672  models.common.Conv                      [16, 32, 3, 2]
#   2                -1  1      4800  models.common.C3                        [32, 32, 1]
#   3                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   4                -1  2     29184  models.common.C3                        [64, 64, 2]
#   5                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   6                -1  3    156928  models.common.C3                        [128, 128, 3]
#   7                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   8                -1  1    296448  models.common.C3                        [256, 256, 1]
#   9                -1  1    164608  models.common.SPPF                      [256, 256, 5]
#  10                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  14                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     22912  models.common.C3                        [128, 64, 1, False]
#  18                -1  1     36992  models.common.Conv                      [64, 64, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1     74496  models.common.C3                        [128, 128, 1, False]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  24      [17, 20, 23]  1     12177  models.yolo.Detect                      [4, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [64, 128, 256]]
# Model summary: 214 layers, 1769329 parameters, 1769329 gradients, 4.2 GFLOPs
#
# Transferred 349/349 items from model1_tGD6z2Yw7yqiY1g6.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: float division by zero
# train: Scanning /home/work/KISTI_PCB2/C1_PCB/train/labels.cache... 570 images, 2
# val: Scanning /home/work/KISTI_PCB2/C1_PCB/valid/labels.cache... 44 images, 0 ba
#
# AutoAnchor: 4.73 anchors/target, 0.998 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/C1_PCB_results/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/C1_PCB_results
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/299         4G    0.05435    0.02893   0.005328         80        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.542      0.523      0.496       0.21
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/299         4G    0.05192    0.02421   0.004134         85        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.762      0.405      0.524      0.209
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/299         4G    0.05124    0.02484   0.003751        109        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.511      0.513      0.478      0.209
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/299         4G    0.05145    0.02355   0.003726        111        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181        0.8      0.319      0.485      0.197
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/299         4G    0.05269    0.02526   0.003481        103        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.505      0.606      0.503      0.189
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/299         4G    0.05213    0.02251   0.003437         99        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.691      0.333      0.427      0.161
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/299         4G    0.05505    0.02433   0.003745         97        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.629      0.456      0.467      0.167
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/299         4G    0.05354    0.02516   0.004028         98        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.689      0.403      0.421      0.129
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/299         4G    0.05239    0.02351   0.002914        142        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.623      0.358      0.425      0.179
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/299         4G     0.0537    0.02359   0.003462        109        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.369      0.474      0.369      0.134
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/299         4G    0.05169    0.02225   0.003003        104        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.658       0.37      0.403      0.164
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/299         4G    0.05294    0.02293   0.003448         76        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.489      0.388      0.353      0.145
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/299         4G    0.05329    0.02309   0.003111        101        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.547      0.361      0.384      0.157
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/299         4G    0.05367    0.02406   0.003189         85        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.542      0.373       0.39      0.131
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/299         4G    0.05204    0.02297     0.0024        102        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.553      0.483      0.462      0.169
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/299         4G    0.05057     0.0245   0.002737         95        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.615      0.444      0.474      0.166
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/299         4G    0.05075    0.02368   0.002418         98        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.429       0.46      0.406      0.124
# Stopping training early as no improvement observed in last 15 epochs. Best results observed at epoch 1, best model saved as best.pt.
# To update EarlyStopping(patience=15) pass a new patience value, i.e. `python train.py --patience 300` or use `--patience 0` to disable EarlyStopping.
#
# 17 epochs completed in 0.030 hours.
# Optimizer stripped from runs/train/C1_PCB_results/weights/last.pt, 3.9MB
# Optimizer stripped from runs/train/C1_PCB_results/weights/best.pt, 3.9MB
#
# Validating runs/train/C1_PCB_results/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 1764577 parameters, 0 gradients, 4.1 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.761      0.405      0.524      0.209
#                SCRATCH         44        103      0.791      0.437       0.59      0.179
#           DELAMINATION         44         15      0.519      0.533      0.345       0.11
#             POP_CORN_1         44         57      0.735      0.649      0.688      0.277
#             POP_CORN_2         44          6          1          0      0.473      0.272
# Results saved to runs/train/C1_PCB_results
# Round 2 Start
#
# Connected to Flask-SocketIO server
# Using cache found in /home/work/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-10-19 Python-3.8.10 torch-2.1.0+cu121 CUDA:0 (Quadro RTX 8000, 48593MiB)
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients, 4.5 GFLOPs
# Adding AutoShape...
# train: weights=model2_tGD6z2Yw7yqiY1g6.pt, cfg=, data=/home/work/KISTI_PCB2/C1_PCB/PCB.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=C1_PCB_results, exist_ok=True, quad=False, cos_lr=False, label_smoothing=0.0, patience=15, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 3 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.8.10 torch-2.1.0+cu121 CUDA:0 (Quadro RTX 8000, 48593MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1760  models.common.Conv                      [3, 16, 6, 2, 2]
#   1                -1  1      4672  models.common.Conv                      [16, 32, 3, 2]
#   2                -1  1      4800  models.common.C3                        [32, 32, 1]
#   3                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   4                -1  2     29184  models.common.C3                        [64, 64, 2]
#   5                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   6                -1  3    156928  models.common.C3                        [128, 128, 3]
#   7                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   8                -1  1    296448  models.common.C3                        [256, 256, 1]
#   9                -1  1    164608  models.common.SPPF                      [256, 256, 5]
#  10                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  14                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     22912  models.common.C3                        [128, 64, 1, False]
#  18                -1  1     36992  models.common.Conv                      [64, 64, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1     74496  models.common.C3                        [128, 128, 1, False]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  24      [17, 20, 23]  1     12177  models.yolo.Detect                      [4, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [64, 128, 256]]
# Model summary: 214 layers, 1769329 parameters, 1769329 gradients, 4.2 GFLOPs
#
# Transferred 349/349 items from model2_tGD6z2Yw7yqiY1g6.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: float division by zero
# train: Scanning /home/work/KISTI_PCB2/C1_PCB/train/labels.cache... 570 images, 2
# val: Scanning /home/work/KISTI_PCB2/C1_PCB/valid/labels.cache... 44 images, 0 ba
#
# AutoAnchor: 4.73 anchors/target, 0.998 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/C1_PCB_results/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/C1_PCB_results
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/299         4G    0.05157    0.02481   0.004079         80        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.398      0.546      0.537      0.211
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/299         4G    0.05024    0.02349   0.003251         85        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.474      0.556      0.566      0.211
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/299         4G    0.05089    0.02467   0.003483        109        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.472      0.556      0.499      0.189
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/299         4G    0.05139    0.02344   0.003496        111        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.556      0.494      0.482      0.178
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/299         4G    0.05251    0.02517   0.003274        103        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.566      0.485      0.506      0.183
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/299         4G    0.05208    0.02231   0.003393         99        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.617      0.462      0.425       0.15
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/299         4G    0.05514    0.02417   0.003618         97        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.515      0.521      0.481      0.167
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/299         4G    0.05378    0.02481   0.003833         98        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.561      0.431      0.415      0.119
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/299         4G    0.05301    0.02352   0.002987        142        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.499      0.408       0.43      0.142
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/299         4G    0.05372    0.02378   0.003688        109        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.557      0.397      0.441      0.145
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/299         4G    0.05096    0.02259   0.002926        104        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.388       0.39       0.33     0.0967
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/299         4G    0.05334    0.02358   0.003429         76        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.625      0.419      0.413      0.134
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/299         4G    0.05432    0.02328    0.00311        101        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181       0.39      0.342       0.31      0.103
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/299         4G    0.05317    0.02427    0.00294         85        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.496       0.38      0.333      0.105
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/299         4G      0.053    0.02298   0.002688        102        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181       0.38      0.379       0.36      0.112
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/299         4G    0.05091    0.02453   0.002475         95        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.514      0.393      0.415      0.132
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/299         4G     0.0498    0.02373   0.002256         98        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.599      0.427      0.445      0.156
# Stopping training early as no improvement observed in last 15 epochs. Best results observed at epoch 1, best model saved as best.pt.
# To update EarlyStopping(patience=15) pass a new patience value, i.e. `python train.py --patience 300` or use `--patience 0` to disable EarlyStopping.
#
# 17 epochs completed in 0.029 hours.
# Optimizer stripped from runs/train/C1_PCB_results/weights/last.pt, 3.9MB
# Optimizer stripped from runs/train/C1_PCB_results/weights/best.pt, 3.9MB
#
# Validating runs/train/C1_PCB_results/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 1764577 parameters, 0 gradients, 4.1 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.476      0.559      0.567      0.211
#                SCRATCH         44        103      0.494      0.689      0.644      0.204
#           DELAMINATION         44         15      0.277      0.533      0.364      0.106
#             POP_CORN_1         44         57      0.507      0.719      0.694      0.268
#             POP_CORN_2         44          6      0.628      0.295      0.565      0.268
# Results saved to runs/train/C1_PCB_results
# Round 3 Start
#
# Connected to Flask-SocketIO server
# Using cache found in /home/work/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-10-19 Python-3.8.10 torch-2.1.0+cu121 CUDA:0 (Quadro RTX 8000, 48593MiB)
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients, 4.5 GFLOPs
# Adding AutoShape...
# train: weights=model3_tGD6z2Yw7yqiY1g6.pt, cfg=, data=/home/work/KISTI_PCB2/C1_PCB/PCB.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=C1_PCB_results, exist_ok=True, quad=False, cos_lr=False, label_smoothing=0.0, patience=15, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 3 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.8.10 torch-2.1.0+cu121 CUDA:0 (Quadro RTX 8000, 48593MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1760  models.common.Conv                      [3, 16, 6, 2, 2]
#   1                -1  1      4672  models.common.Conv                      [16, 32, 3, 2]
#   2                -1  1      4800  models.common.C3                        [32, 32, 1]
#   3                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   4                -1  2     29184  models.common.C3                        [64, 64, 2]
#   5                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   6                -1  3    156928  models.common.C3                        [128, 128, 3]
#   7                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   8                -1  1    296448  models.common.C3                        [256, 256, 1]
#   9                -1  1    164608  models.common.SPPF                      [256, 256, 5]
#  10                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  14                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     22912  models.common.C3                        [128, 64, 1, False]
#  18                -1  1     36992  models.common.Conv                      [64, 64, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1     74496  models.common.C3                        [128, 128, 1, False]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  24      [17, 20, 23]  1     12177  models.yolo.Detect                      [4, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [64, 128, 256]]
# Model summary: 214 layers, 1769329 parameters, 1769329 gradients, 4.2 GFLOPs
#
# Transferred 349/349 items from model3_tGD6z2Yw7yqiY1g6.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: float division by zero
# train: Scanning /home/work/KISTI_PCB2/C1_PCB/train/labels.cache... 570 images, 2
# val: Scanning /home/work/KISTI_PCB2/C1_PCB/valid/labels.cache... 44 images, 0 ba
#
# AutoAnchor: 4.73 anchors/target, 0.998 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/C1_PCB_results/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/C1_PCB_results
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/299         4G    0.05078    0.02449   0.003469         80        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181       0.51      0.594      0.545      0.211
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/299         4G    0.04908    0.02319    0.00275         85        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.465      0.584      0.563        0.2
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/299         4G    0.05074    0.02461   0.003374        109        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.552      0.547      0.543       0.22
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/299         4G    0.05142    0.02338   0.003339        111        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.495      0.438      0.535      0.186
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/299         4G    0.05248    0.02504   0.003155        103        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.566      0.474      0.499      0.181
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/299         4G    0.05228    0.02238   0.003302         99        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181       0.62      0.414      0.439      0.145
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/299         4G    0.05499    0.02439   0.003777         97        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.606      0.492      0.473      0.171
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/299         4G    0.05373    0.02508   0.004073         98        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181       0.55      0.409      0.377      0.106
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/299         4G    0.05308    0.02355   0.002913        142        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.532      0.391      0.408      0.149
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/299         4G    0.05425    0.02389   0.003548        109        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.457      0.409      0.397      0.141
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/299         4G    0.05138    0.02249    0.00327        104        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.517      0.365      0.389      0.142
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/299         4G    0.05286    0.02306   0.003035         76        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.529       0.37      0.399      0.127
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/299         4G    0.05389     0.0231   0.002964        101        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.444       0.36      0.383      0.125
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/299         4G    0.05322    0.02422   0.002859         85        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.468      0.464      0.409      0.128
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/299         4G    0.05251    0.02299   0.002399        102        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.544      0.445      0.402      0.139
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/299         4G    0.05086    0.02408    0.00234         95        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.408      0.492      0.433      0.139
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/299         4G    0.05078    0.02372    0.00274         98        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.654      0.375      0.413      0.153
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/299         4G     0.0513    0.02387   0.002547         89        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.726      0.485      0.502      0.173
# Stopping training early as no improvement observed in last 15 epochs. Best results observed at epoch 2, best model saved as best.pt.
# To update EarlyStopping(patience=15) pass a new patience value, i.e. `python train.py --patience 300` or use `--patience 0` to disable EarlyStopping.
#
# 18 epochs completed in 0.031 hours.
# Optimizer stripped from runs/train/C1_PCB_results/weights/last.pt, 3.9MB
# Optimizer stripped from runs/train/C1_PCB_results/weights/best.pt, 3.9MB
#
# Validating runs/train/C1_PCB_results/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 1764577 parameters, 0 gradients, 4.1 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.552      0.547      0.543       0.22
#                SCRATCH         44        103       0.71      0.573       0.65      0.204
#           DELAMINATION         44         15       0.39      0.467       0.34      0.101
#             POP_CORN_1         44         57      0.554      0.649      0.622      0.249
#             POP_CORN_2         44          6      0.552        0.5      0.562      0.327
# Results saved to runs/train/C1_PCB_results
# Round 4 Start
#
# Connected to Flask-SocketIO server
# Using cache found in /home/work/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-10-19 Python-3.8.10 torch-2.1.0+cu121 CUDA:0 (Quadro RTX 8000, 48593MiB)
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients, 4.5 GFLOPs
# Adding AutoShape...
# train: weights=model4_tGD6z2Yw7yqiY1g6.pt, cfg=, data=/home/work/KISTI_PCB2/C1_PCB/PCB.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=C1_PCB_results, exist_ok=True, quad=False, cos_lr=False, label_smoothing=0.0, patience=15, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 3 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.8.10 torch-2.1.0+cu121 CUDA:0 (Quadro RTX 8000, 48593MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1760  models.common.Conv                      [3, 16, 6, 2, 2]
#   1                -1  1      4672  models.common.Conv                      [16, 32, 3, 2]
#   2                -1  1      4800  models.common.C3                        [32, 32, 1]
#   3                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   4                -1  2     29184  models.common.C3                        [64, 64, 2]
#   5                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   6                -1  3    156928  models.common.C3                        [128, 128, 3]
#   7                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   8                -1  1    296448  models.common.C3                        [256, 256, 1]
#   9                -1  1    164608  models.common.SPPF                      [256, 256, 5]
#  10                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  14                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     22912  models.common.C3                        [128, 64, 1, False]
#  18                -1  1     36992  models.common.Conv                      [64, 64, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1     74496  models.common.C3                        [128, 128, 1, False]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  24      [17, 20, 23]  1     12177  models.yolo.Detect                      [4, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [64, 128, 256]]
# Model summary: 214 layers, 1769329 parameters, 1769329 gradients, 4.2 GFLOPs
#
# Transferred 349/349 items from model4_tGD6z2Yw7yqiY1g6.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: float division by zero
# train: Scanning /home/work/KISTI_PCB2/C1_PCB/train/labels.cache... 570 images, 2
# val: Scanning /home/work/KISTI_PCB2/C1_PCB/valid/labels.cache... 44 images, 0 ba
#
# AutoAnchor: 4.73 anchors/target, 0.998 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/C1_PCB_results/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/C1_PCB_results
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/299         4G    0.04996    0.02411   0.002814         80        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.575      0.553      0.556       0.21
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/299         4G    0.04737    0.02259   0.002141         85        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.552      0.533       0.54      0.189
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/299         4G     0.0487    0.02398   0.002257        109        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.632      0.535      0.558      0.197
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/299         4G    0.05135     0.0233   0.003109        111        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.568      0.496      0.511      0.178
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/299         4G    0.05215    0.02491   0.003114        103        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.613      0.461      0.502      0.169
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/299         4G    0.05218    0.02252   0.003259         99        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181       0.59      0.462      0.432      0.159
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/299         4G    0.05468    0.02458   0.003841         97        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181       0.52        0.4      0.372      0.136
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/299         4G     0.0543    0.02532   0.004098         98        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.383      0.302      0.303     0.0876
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/299         4G    0.05346    0.02384   0.003125        142        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.522      0.325      0.337      0.107
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/299         4G    0.05422    0.02381   0.003389        109        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.495      0.437      0.411      0.144
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/299         4G    0.05189     0.0227    0.00308        104        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.366      0.448      0.361     0.0942
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/299         4G    0.05358     0.0233   0.003834         76        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.393      0.459      0.405      0.124
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/299         4G    0.05463    0.02366   0.003138        101        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.344      0.463      0.352      0.115
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/299         4G    0.05311    0.02409   0.003129         85        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.472      0.427      0.382      0.119
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/299         4G    0.05282    0.02303    0.00275        102        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.514      0.394      0.384      0.107
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/299         4G    0.05105    0.02414   0.002257         95        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.616      0.485      0.431       0.15
# Stopping training early as no improvement observed in last 15 epochs. Best results observed at epoch 0, best model saved as best.pt.
# To update EarlyStopping(patience=15) pass a new patience value, i.e. `python train.py --patience 300` or use `--patience 0` to disable EarlyStopping.
#
# 16 epochs completed in 0.028 hours.
# Optimizer stripped from runs/train/C1_PCB_results/weights/last.pt, 3.9MB
# ...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/299         4G    0.05224    0.02249   0.002751        104        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.471      0.397      0.328       0.12
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/299         4G    0.05318    0.02315   0.003708         76        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.502      0.352       0.33       0.11
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/299         4G    0.05312    0.02313     0.0029        101        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.456      0.314      0.354      0.123
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/299         4G     0.0532    0.02405   0.002859         85        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.381       0.36      0.374      0.124
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/299         4G    0.05239    0.02307   0.002307        102        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.405      0.462      0.365      0.117
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/299         4G    0.05025    0.02426   0.002286         95        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.755      0.358      0.437      0.144
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/299         4G     0.0512    0.02384   0.002457         98        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.547      0.441       0.44      0.144
# Stopping training early as no improvement observed in last 15 epochs. Best results observed at epoch 1, best model saved as best.pt.
# To update EarlyStopping(patience=15) pass a new patience value, i.e. `python train.py --patience 300` or use `--patience 0` to disable EarlyStopping.
#
# 17 epochs completed in 0.030 hours.
# Optimizer stripped from runs/train/C1_PCB_results/weights/last.pt, 3.9MB
# Optimizer stripped from runs/train/C1_PCB_results/weights/best.pt, 3.9MB
#
# Validating runs/train/C1_PCB_results/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 1764577 parameters, 0 gradients, 4.1 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.696      0.466       0.58      0.202
#                SCRATCH         44        103      0.795      0.415      0.561      0.172
#           DELAMINATION         44         15      0.417      0.334      0.387      0.114
#             POP_CORN_1         44         57      0.748      0.614      0.664      0.268
#             POP_CORN_2         44          6      0.824        0.5       0.71      0.253
# Results saved to runs/train/C1_PCB_results
# Round 14 Start
#
# Connected to Flask-SocketIO server
# Using cache found in /home/work/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-10-19 Python-3.8.10 torch-2.1.0+cu121 CUDA:0 (Quadro RTX 8000, 48593MiB)
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients, 4.5 GFLOPs
# Adding AutoShape...
# train: weights=model14_tGD6z2Yw7yqiY1g6.pt, cfg=, data=/home/work/KISTI_PCB2/C1_PCB/PCB.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=C1_PCB_results, exist_ok=True, quad=False, cos_lr=False, label_smoothing=0.0, patience=15, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 3 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.8.10 torch-2.1.0+cu121 CUDA:0 (Quadro RTX 8000, 48593MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1760  models.common.Conv                      [3, 16, 6, 2, 2]
#   1                -1  1      4672  models.common.Conv                      [16, 32, 3, 2]
#   2                -1  1      4800  models.common.C3                        [32, 32, 1]
#   3                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   4                -1  2     29184  models.common.C3                        [64, 64, 2]
#   5                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   6                -1  3    156928  models.common.C3                        [128, 128, 3]
#   7                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   8                -1  1    296448  models.common.C3                        [256, 256, 1]
#   9                -1  1    164608  models.common.SPPF                      [256, 256, 5]
#  10                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  14                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     22912  models.common.C3                        [128, 64, 1, False]
#  18                -1  1     36992  models.common.Conv                      [64, 64, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1     74496  models.common.C3                        [128, 128, 1, False]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  24      [17, 20, 23]  1     12177  models.yolo.Detect                      [4, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [64, 128, 256]]
# Model summary: 214 layers, 1769329 parameters, 1769329 gradients, 4.2 GFLOPs
#
# Transferred 349/349 items from model14_tGD6z2Yw7yqiY1g6.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: float division by zero
# train: Scanning /home/work/KISTI_PCB2/C1_PCB/train/labels.cache... 570 images, 2
# val: Scanning /home/work/KISTI_PCB2/C1_PCB/valid/labels.cache... 44 images, 0 ba
#
# AutoAnchor: 4.73 anchors/target, 0.998 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/C1_PCB_results/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/C1_PCB_results
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/299         4G    0.04793    0.02376   0.001769         80        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.507      0.577      0.543      0.195
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/299         4G     0.0451    0.02204   0.001341         85        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.678      0.487      0.576      0.199
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/299         4G    0.04735    0.02376   0.001516        109        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.595      0.508       0.51      0.183
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/299         4G    0.05013    0.02304   0.002026        111        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.574      0.448      0.483      0.155
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/299         4G    0.05357    0.02507   0.003079        103        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.468      0.436      0.408      0.129
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/299         4G    0.05281    0.02294   0.003426         99        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.604      0.454      0.411       0.15
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/299         4G    0.05468    0.02514   0.003859         97        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.387      0.362      0.293     0.0976
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/299         4G    0.05399    0.02556   0.004174         98        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.448      0.351      0.353      0.118
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/299         4G    0.05401    0.02395    0.00319        142        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.479      0.408      0.311      0.104
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/299         4G    0.05405    0.02423   0.003662        109        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181       0.45      0.326      0.347      0.126
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/299         4G    0.05313    0.02265   0.003007        104        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.684      0.352      0.361      0.118
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/299         4G    0.05347     0.0233   0.003863         76        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.595      0.153      0.186     0.0707
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/299         4G    0.05419    0.02318    0.00316        101        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.417      0.389       0.32      0.115
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/299         4G    0.05373    0.02443   0.002754         85        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.452      0.369      0.315      0.102
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/299         4G    0.05213    0.02324   0.002515        102        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.436      0.304      0.342      0.119
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/299         4G    0.05034    0.02433   0.002402         95        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.701      0.388      0.464      0.155
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/299         4G    0.04973     0.0234   0.002134         98        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181        0.5      0.501      0.477       0.17
# Stopping training early as no improvement observed in last 15 epochs. Best results observed at epoch 1, best model saved as best.pt.
# To update EarlyStopping(patience=15) pass a new patience value, i.e. `python train.py --patience 300` or use `--patience 0` to disable EarlyStopping.
#
# 17 epochs completed in 0.028 hours.
# Optimizer stripped from runs/train/C1_PCB_results/weights/last.pt, 3.9MB
# Optimizer stripped from runs/train/C1_PCB_results/weights/best.pt, 3.9MB
#
# Validating runs/train/C1_PCB_results/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 1764577 parameters, 0 gradients, 4.1 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all         44        181      0.678      0.489      0.576      0.199
#                SCRATCH         44        103      0.715      0.476      0.562      0.169
#           DELAMINATION         44         15        0.4      0.356      0.378      0.105
#             POP_CORN_1         44         57      0.732      0.624      0.652       0.25
#             POP_CORN_2         44          6      0.864        0.5      0.714      0.271
# Results saved to runs/train/C1_PCB_results
# Round 15 Start
#
# Connected to Flask-SocketIO server
# Using cache found in /home/work/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-10-19 Python-3.8.10 torch-2.1.0+cu121 CUDA:0 (Quadro RTX 8000, 48593MiB)
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients, 4.5 GFLOPs
# Adding AutoShape...

# %% [markdown]
# ## Test Federated Learning Model (inference)

# %%
if os.getcwd() != '/home/work/KISTI_PCB2/yolov5':
    os.chdir('./yolov5')
os.getcwd()

# %%
for n in range(1, n):
    # !python val.py --data "/home/work/KISTI_PCB2/{client}/PCB.yaml" --weights "model{n}_{token}.pt" --task 'test' --name 'PCB_result_final(federated)_round{n}' --exist-ok

# %% [markdown]
# ## Detect Federated Learning Model

# %%
# !python detect.py --source "/home/work/KISTI_PCB2/{client}/test/images"\
    --weights "model{num_round}_{token}.pt" \
    --exist-ok \
    --line-thickness 2 \
    --name 'PCB_detect_results(federated)'
